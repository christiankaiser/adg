# %% [markdown]
# # Sélection des zones Z05 avec **R**
#
# ## 1) Répertoire de travail et installation du package *foreign*
#
# La table de correspondance entre identifiant des zones z05 et numéros de cantons est contenue dans le fichier **z05.dbf** (table d'attribut de la couche **z05.shp**). Pour lire ce fichier, il faut installer le package `foreign`, puis le "loader" cette librairie à l'aide de la commande `library()`

# %%
install.packages('foreign', repos='http://cran.us.r-project.org')
library(foreign)
# Out:
# The downloaded binary packages are in
# 	/var/folders/cl/3jdthly11f7__5dn34t37vhr0000gn/T//RtmpqTLigX/downloaded_packages

# %%
library(foreign)

# %% [markdown]
# ## 2) Chargement de la table d'attributs et sélection des zones
#
# La librairie *foreign* donne accès à la commande `read.dbf()`, qui permet de lire le fichier **z05.dbf**. Nous pouvons dès lors l'enregistrer dans une variable ici appelée *mapData*

# %%
mapData = read.dbf("z05.dbf")

# %% [markdown]
# Il est possible de sélectionner les données d'un canton spécifique de la manière suivante (ici 22 : Vaud)

# %%
zVD = mapData$Z05[mapData$KT == 22]

# %% [markdown]
# Nous pouvons afficher un aperçu des zones Z05 appartenant au canton de Vaud à l'aide de la commande `head()`

# %%
head(zVD, 10)
# Out:
#  [1] 5841.0 5888.0 5602.0 5793.0 5678.0 5518.0 5646.0 5401.1 5401.2 5407.0

# %% [markdown]
# Pour sélectionner des données appartenant à **plusieurs cantons** différents, il faut utiliser la commande `subset()` (ici 22, 23 : VD, VS). Vous trouverez les numéros de chaque cantons [ici.](https://www.bfs.admin.ch/bfs/fr/home/statistiques/statistique-regions/portraits-regionaux-chiffres-cles/cantons.assetdetail.453863.html)

# %%
zVSVD = subset(mapData$Z05, mapData$KT %in% c(22, 23))
head(zVSVD, 10)
# Out:
#  [1] 5841 5888 5602 5793 5678 5518 5646 6300 6292 6159

# %% [markdown]
# ## 3) Chargement des données statistiques
#
# Dans cette partie, nous importons le jeu de données (ici celui relatif au domaine socio-économique) et nous effectuons un ajustement en renommant l'en-tête de la variable comportant l'information de l'identifiant des zones z05

# %%
donnees = read.csv("soceco.csv", header = T, sep = ";", encoding = "UTF-8")
colnames(donnees)[1] = "Z05"

# %% [markdown]
# Voici un aperçu de ces données à l'aide de la commande *head()*

# %%
head(donnees)
# Out:
#   Z05 NAME                                  PLUGER PLUFRA PLUITA PLURUM PLUENG
# 1 1.0 Reppischtal                           3526   82      36    0       68
# 2 2.1 Affoltern am Albis Zentrum            4475   15     180    0       43
# 3 2.2 Affoltern am Albis-Zwillikon Hedingen 4263   41     166    0      117
# 4 3.0 Bonstetten                            3611    9      64    7       40
# 5 4.0 Oberalbis                             3895   24      16    0       74
# 6 9.0 Mettmenstetten                        4858   41     120    8       79
#   PLUOTH PLU2GF PLU2GI ⋯ ADD3FIN ADD3RE ADD3PRO ADD3SUP ADD3ADM ADD3EDU ADD3HC
# 1 160    24      47    ⋯ 464     57     403      75     101     149     130
# 2 730    42     238    ⋯ 302     39     297     145     117     164     288
# 3 228    43     168    ⋯ 320     42     281     114     201     194     326
# 4 166    63      80    ⋯ 409     31     324      80     116     187     155
# 5 108    22      66    ⋯ 158     23     331     111     147     282     188
# 6 235    45      45    ⋯ 327      8     326      88     197     288     260
#   ADD3SOC ADD3REC ADD3PER
# 1  95      9      104
# 2 132     39      147
# 3 146     18       91
# 4  89     16       57
# 5 134     16      103
# 6 139     49       64

# %% [markdown]
# ## 4) Correspondance entre les zones Z05 et les données brutes avec `match()`
#
# La commande `match()` permet d'identifier les numéros des lignes du jeu de données (`donnees$z05`) dont l'identifiant z05 "match" les identifiants des zones z05 du canton de Vaud (`zVD`). Ces numéros de lignes sont enregistrés dans la variable `rowData`. La commande `length()` permet de vérifier le nombre de *matchs*, qui doit être égal au nombre de zones z05 du canton.

# %%
rowDataVSVD = match(zVSVD, donnees$Z05)
length(rowDataVD)
# Out:
# [1] 128

# %% [markdown]
# ## 5) Extraction des données de la région
# Pour extraire les données du canton de Vaud, nous les enregistrons dans une nouvelle variable appelée `DonneesVD`, constitutée sur la base d'une sélections des lignes (celles de `rowData`) du jeu de `donnees`

# %%
DonneesVSVD = donnees[rowDataVSVD,]

# %% [markdown]
# Le résultat est ainsi composé des données des zones z05 des **deux cantons** Valais et Vaud

# %%
head(DonneesVSVD, 20)
# Out:
#      Z05    NAME                       PLUGER PLUFRA PLUITA PLURUM PLUENG
# 1164 5841.0 Enhaut                      187   2611    17    0      126
# 1176 5888.0 Saint-Légier-La Chiésaz     170   2701    41    0      240
# 1121 5602.0 Bourg-en-Lavaux             145   2896    36    0       97
# 1160 5793.0 Oron                         38   3267    16    0       31
# 1140 5678.0 Moudon                       43   2214    33    0        8
# 1077 5518.0 Echallens                    42   3320    45    0       16
# 1137 5646.0 Saint-Prex                   87   2593   100    0       96
# 1239 6300.0 Zermatt                    2731    117   149    0       93
# 1236 6292.0 Mattertal                  3318     24    26    0        0
# 1216 6159.0 Vouvry-Vionnaz               80   3859    62    0       16
# 1214 6154.0 Port-Valais St-Gingolph      49   2575    27    0       28
# 1060 5401.1 Aigle Ville                  39   2603    67    0       22
# 1061 5401.2 Aigle Emoz-Pousaz            50   1829    50    0       17
# 1063 5407.0 Ormonts-Leysin               43   2791    42    0      180
# 1067 5414.0 Villeneuve                   83   2287    85    0       52
# 1066 5413.0 Roche-Bas Chablais Vaudois   47   2684    28    0       52
# 1062 5402.1 Bex-Village Lavey-Morcles    85   3425    64    0       24
# 1064 5409.1 Ollon-Village Bex-Fenalet    69   2917    12    0       82
# 1065 5409.2 Villars-Gryon                24   1895    29    0      266
# 1068 5422.0 Aubonne-Perroy              100   3281    57    4      180
#      PLUOTH PLU2GF PLU2GI ⋯ ADD3FIN ADD3RE ADD3PRO ADD3SUP ADD3ADM ADD3EDU
# 1164 283    172     0     ⋯  59      48    123      83      95     102
# 1176 200    210     0     ⋯ 211      23    311      98     117     188
# 1121 197    198     0     ⋯ 164      36    258      85      90     164
# 1160 232    155     0     ⋯  91      35    161     107     187     150
# 1140 661     77     0     ⋯  67      17    118      94      95      83
# 1077 327    113     0     ⋯ 149      39    174     112     192     113
# 1137 453    159     4     ⋯ 255      29    204     115      80     166
# 1239 643    103    49     ⋯  42      17     92      40      67      86
# 1236 417     64    34     ⋯  69       8     88      72      74      50
# 1216 322    136     0     ⋯ 118      41    168     150     160     140
# 1214 282    121     0     ⋯  57      19    168      64     104      96
# 1060 370    116     0     ⋯  59      24    177      90     101     139
# 1061 708     73     0     ⋯  80      29     85     127     114      79
# 1063 260    134     0     ⋯  64      51    101     120      70     280
# 1067 453     89     0     ⋯  92      36    137      91      87      74
# 1066 166    139     0     ⋯ 130      14    147      82     116     142
# 1062 577    157     0     ⋯ 106      41    178     119     110     120
# 1064 105    126     0     ⋯ 106      25    189      46     188     232
# 1065 383     82     0     ⋯  57     113     70      79      61     353
# 1068 291    223     0     ⋯ 253      40    275     122     144     163
#      ADD3HC ADD3SOC ADD3REC ADD3PER
# 1164 168     70     25       47
# 1176 205    129     28       72
# 1121 234    103     36       88
# 1160 215    165     46       86
# 1140 130    143     20       48
# 1077 181    183     34      109
# 1137 118    144     40       65
# 1239  33     76     66       34
# 1236  45    114     15       42
# 1216 216    210     41       47
# 1214 121     67     26       65
# 1060 179    125     35       24
# 1061 149     72     21       53
# 1063 167    108     53       35
# 1067 135     98     42       48
# 1066 142    101     16       44
# 1062 155    151     20       51
# 1064 164    104     28       19
# 1065  33     44     41       49
# 1068 159     98     42      106

# %% [markdown]
# # 6) Exportation du *data-frame* en format CSV
# Une fois les modifications effectuées sur votre data-frame, il vous est possible de l'exporter à nouveau en csv à l'aide de la fonction write.csv() de la manière suivante:

# %%
write.csv(DonneesVSVD, file = "DonneesVSVD.csv", fileEncoding = "UTF-8")

# %% [markdown]
# Pour s'assurer que tout a bien fonctionné nous pouvons charger le fichier à l'aide de `read.csv()`

# %%
read.csv(file="DonneesVSVD.csv", sep=",")
# Out:
#     X    Z05      NAME                                PLUGER PLUFRA PLUITA
# 1   1164 5841.0   Enhaut                               187   2611    17
# 2   1176 5888.0   Saint-Légier-La Chiésaz              170   2701    41
# 3   1121 5602.0   Bourg-en-Lavaux                      145   2896    36
# 4   1160 5793.0   Oron                                  38   3267    16
# 5   1140 5678.0   Moudon                                43   2214    33
# 6   1077 5518.0   Echallens                             42   3320    45
# 7   1137 5646.0   Saint-Prex                            87   2593   100
# 8   1239 6300.0   Zermatt                             2731    117   149
# 9   1236 6292.0   Mattertal                           3318     24    26
# 10  1216 6159.0   Vouvry-Vionnaz                        80   3859    62
# 11  1214 6154.0   Port-Valais St-Gingolph               49   2575    27
# 162 0       65     514   134    ⋯ 122      49    150     128     125
# 163 0       28     321   163    ⋯ 155      27    185     118     138
# 164 0       98     578   103    ⋯ 244      37    148     153      63
# 165 0      331     234   101    ⋯ 214      24    209     104      72
# 166 0      101     372    75    ⋯ 218      44    119     187      56
# 167 0      133     453    95    ⋯ 216      40    201     164      76
# 168 0       64     663   103    ⋯ 128      29    123     141      56
# 169 0       49     495   126    ⋯ 144      37    170      72      53
# 170 0      181     231   186    ⋯ 161      91    239     135      99
# 171 0       91     325   130    ⋯ 134      24    166      92     122
# 172 0       34     165   161    ⋯  89      17    121      47     139
# 173 0       24     291   139    ⋯  40      35    106      36      62
# 174 0        8     149   127    ⋯ 111      75    118      76     129
# 175 0       37     424   145    ⋯  39     121     81      62      17
# 176 0       30     473   155    ⋯ 189      41    210     104     121
# 177 0        8     240   173    ⋯ 147      51    195      18     185
# 178 0       12     534   226    ⋯ 123      66    140     140     145
# 179 4        0     674   132    ⋯ 117      47    180      45     165
# 180 0        9     441   130    ⋯  74      15    183     103     109
#     ADD3EDU ADD3HC ADD3SOC ADD3REC ADD3PER
# 1   102     168     70     25       47
# 2   188     205    129     28       72
# 3   164     234    103     36       88
# 4   150     215    165     46       86
# 5    83     130    143     20       48
# 6   113     181    183     34      109
# 7   166     118    144     40       65
# 8    86      33     76     66       34
# 9    50      45    114     15       42
# 10  140     216    210     41       47
# 11   96     121     67     26       65
# 12  139     179    125     35       24
# 13   79     149     72     21       53
# 14  280     167    108     53       35
# 15   74     135     98     42       48
# 16  142     142    101     16       44
# 17  120     155    151     20       51
# 18  232     164    104     28       19
# 19  353      33     44     41       49
# 20  163     159     98     42      106
# 21  221     161    146     53       91
# 22  221     242    185     32       98
# 23  170     202    133     28       54
# 24  103     191    217     16       83
# 25  215     197    213     23      114
# 26  191     267    190     67      110
# 27  183     234    198     60      115
# 28   79     113     87     16       23
# 29  236     269    137     27       78
# 30  154     198     94     33       31
# ⋮   ⋮       ⋮      ⋮       ⋮       ⋮
# 151 120     194    161     30       48
# 152  57     151    167     16      100
# 153 206     180    154     19      111
# 154 321     144    168     58       97
# 155  97      74     83     16       55
# 156 101      80     93     20       42
# 157 156     123     99     24       54
# 158 127     103    138     17       71
# 159 230     252    106     54       96
# 160 156     183    216     62      101
# 161 101     151    145     29      124
# 162 121     141    179     21       85
# 163 124     144    150     32       84
# 164 117     158    133     25      206
# 165  80     127     68     63      121
# 166 108      83     91     24      137
# 167 119     133    116     34      128
# 168 111     152    175     54       69
# 169 127     139     99     38       60
# 170 153     187    105     21       80
# 171 125     165    134     49      102
# 172 152     211    151     16       65
# 173  70     240     60     25       26
# 174 139     200    136     33       49
# 175  42     141     34     36       34
# 176 213     269    140     32      112
# 177 193     255    122     44       82
# 178 138     111    112     80       58
# 179 110     319     81     32       77
# 180 150     217    109      8       87
